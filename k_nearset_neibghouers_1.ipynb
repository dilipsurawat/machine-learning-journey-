# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('breast-cancer.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df[df['area_mean']>=2100]
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 180     873592         M        27.22         21.87           182.1
# 212    8810703         M        28.11         18.47           188.5
# 461  911296202         M        27.42         26.27           186.9
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 180     2250.0           0.1094            0.1914          0.2871
# 212     2499.0           0.1142            0.1516          0.3201
# 461     2501.0           0.1084            0.1988          0.3635
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 180               0.1878  ...         33.12          32.85            220.8
# 212               0.1595  ...         28.11          18.47            188.5
# 461               0.1689  ...         36.04          31.37            251.2
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# ...

# %%
h = df['radius_mean'].plot(kind='hist')
h.set_xlabel('radius_mean ')
h.set_ylabel("frequency in percantage")
h.set_title("radius_mean  distribution graph")
# Out:
# Text(0.5, 1.0, 'radius_mean  distribution graph')

# %%
df.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33            184.6      2019.0
# 1  ...         24.99          23.41            158.8      1956.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
#
#    symmetry_worst  fractal_dimension_worst
# ...

# %%
df.drop(columns=['id'],inplace=True)

# %%
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2,random_state=11)

# %%
x_train.shape
# Out:
# (455, 30)

# %%
y_test.shape
# Out:
# (114,)

# %%
# now we transforming over data becuse we apply k nearset neighbours they best on distance caluculation on data points and my data many columns 
# have higher value and some lower value they make mistake in prediction

# we apply standard scaller

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
x_train.shape
# Out:
# (455, 30)

# %%
# accuracy on traning data 
#knn.score(x_train[0:455:10],y_train[0:455:10])

# %%
# accuracy on test data (unseen dataset)
#knn.score(x_test,y_test)

# %%
from sklearn.metrics import accuracy_score

y_pred = knn.predict(x_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158

# %%
# finding best k value that give a best accuracy over data so lets start
score = []
for i in range(1,16):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)

    y_pred = knn.predict(x_test)

    score.append(accuracy_score(y_test,y_pred))

# %%
score
# Out:
# [0.9385964912280702,
#  0.9473684210526315,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9736842105263158,
#  0.956140350877193,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9824561403508771]

# %%
plt.plot(range(1,16),score)
