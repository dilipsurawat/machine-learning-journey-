# %%
import pandas as pd 
import numpy as np
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt

# %%
data = load_diabetes()
data
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]], shape=(442, 10)),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
X = data.data
y = data.target

# %%
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
#df.rename(columns={'0':'age','1':'sex','2':'bmi','3':'bp','4':'s1','5':'s2','6':'s3','7':'s4','8':'s5','9':'s6'},inplace=True)

# %%
# now we train over model using linear regression than check accuracy than we again train this by rigde regularization se
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=45)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

print("r2 score",r2_score(y_test,y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score 0.5188113124539249
# RMSE 48.72713760953252

# %%
# now we do same task by ridge regularization 

from sklearn.linear_model import Ridge

r = Ridge(alpha=0.0001)

r.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
y_predc = r.predict(x_test)

# %%
print('r2_score',r2_score(y_test,y_predc))
print('RMSE',np.sqrt(mean_squared_error(y_test,y_predc)))
# Out:
# r2_score 0.518973263588495
# RMSE 48.718937001819555

# %%
x_trans = X[0:350:5]

y_trains = y[0:350:5]

# %%
x_trans
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187239, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990749, -0.01764613],
#        [-0.09269548, -0.04464164, -0.04069594, -0.01944183, -0.06899065,
#         -0.07928784,  0.04127682, -0.0763945 , -0.04117617, -0.09634616],
#        [-0.09632802, -0.04464164, -0.08380842,  0.00810098, -0.10338947,
#         -0.09056119, -0.01394774, -0.0763945 , -0.06291688, -0.03421455],
#        [-0.05273755,  0.05068012, -0.01806189,  0.08040085,  0.08924393,
#          0.10766179, -0.03971921,  0.1081111 ,  0.03606033, -0.04249877],
#        [-0.04910502, -0.04464164, -0.05686312, -0.04354178, -0.04559945,
#         -0.04327577,  0.00077881, -0.03949338, -0.01189685,  0.01549073],
#        [-0.06726771,  0.05068012, -0.01267283, -0.04009893, -0.01532849,
#          0.00463594, -0.0581274 ,  0.03430886,  0.01919647, -0.03421455],
#        [-0.06000263, -0.04464164,  0.04445121, -0.01944183, -0.00982468,
# ...

# %%
y_predict = model.predict(x_trans)

# %%
print(r2_score(y_trains,y_predict))
print(np.sqrt(mean_squared_error(y_trains,y_predict)))
# Out:
# 0.537846277032089
# 50.96469490252744

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

X,y = make_regression(n_samples=100, n_features=1,n_informative=1, n_targets=1 , noise=20, random_state=13)

# %%
plt.figure(figsize=(8,5))
plt.scatter(X,y,c=y,cmap='winter')

# %% [markdown]
# ## Now we create over class from scratch ridge regression so lets start by maths

# %%
# Out:
# [24.9546267] [-2.126913]
